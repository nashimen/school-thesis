# %%
# python 3.6
# tensorflow 2.3.1 cpu
# sklearn.__version__ == 0.23.2

import pandas as pd
import numpy as np
import pickle 
from time import time

from sklearn.utils import shuffle # shuffle打乱样本的顺序，它只会打乱样本的顺序，每个样本的数据维持不变。
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import GridSearchCV

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

def save_obj(obj, file):
    with open(file, 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(file ):
    with open(file, 'rb') as f:
        return pickle.load(f)

# %%
# 评价指标函数
def f1_score_get(precision, recall):
    # tf.keras.backend.epsilon() 的值为 1e-07
    # 1.0e-7 == tf.keras.backend.epsilon() 得到 True
    f1 = 2 * precision * recall/( precision + recall + 1.0e-7 )
    return f1

# valid_y:真实标签
# predict_y:预测标签
def eval_p_r_f1(valid_y, predict_y):
    # precision 0 1 2 3
    # setting labels=[pos_label] and average != 'binary' will report scores for that label only.
    accuracy = accuracy_score(
                    y_true = valid_y,
                    y_pred = predict_y
                              )
    
    precision_0 = precision_score(
                    y_true = valid_y,
                    y_pred = predict_y,
                    labels = [0],
                    pos_label = 0,
                    average = 'micro'
                    )

    precision_1 = precision_score(
                    y_true = valid_y,
                    y_pred = predict_y,
                    labels = [1],
                    pos_label = 1,
                    average = 'micro'
                    )

    precision_2 = precision_score(
                    y_true = valid_y,
                    y_pred = predict_y,
                    labels = [2],
                    pos_label = 2,
                    average = 'micro'
                    )

    precision_3 = precision_score(
                    y_true = valid_y,
                    y_pred = predict_y,
                    labels = [3],
                    pos_label = 3,
                    average = 'micro'
                    )
    # recall 0 1 2 3
    recall_0 = recall_score(
                    y_true = valid_y,
                    y_pred = predict_y,
                    labels = [0],
                    pos_label = 0,
                    average = 'micro'
                    )

    recall_1 = recall_score(
                    y_true = valid_y,
                    y_pred = predict_y,
                    labels = [1],
                    pos_label = 1,
                    average = 'micro'
                    )

    recall_2 = recall_score(
                    y_true = valid_y,
                    y_pred = predict_y,
                    labels = [2],
                    pos_label = 2,
                    average = 'micro'
                    )

    recall_3 = recall_score(
                    y_true = valid_y,
                    y_pred = predict_y,
                    labels = [3],
                    pos_label = 3,
                    average = 'micro'
                    )
    
    # f1_score 0 1 2 3
    f1_score_0 = f1_score_get( precision_0, recall_0 )
    f1_score_1 = f1_score_get( precision_1, recall_1 )
    f1_score_2 = f1_score_get( precision_2, recall_2 )
    f1_score_3 = f1_score_get( precision_3, recall_3 )
    
    #由y_true 计算各标签权重
    num_0 = np.sum(valid_y==0)
    num_1 = np.sum(valid_y==1)
    num_2 = np.sum(valid_y==2)
    num_3 = np.sum(valid_y==3)
    
    total = num_0 + num_1 + num_2 + num_3
    p_0 = num_0/total
    p_1 = num_1/total
    p_2 = num_2/total
    p_3 = num_3/total
    
    precision_avg = p_0 * precision_0 + p_1 * precision_1 + p_2 * precision_2 + p_3 * precision_3
    recall_avg = p_0 * recall_0 + p_1 * recall_1 + p_2 * recall_2 + p_3 * recall_3
    f1_score_avg = p_0 * f1_score_0 + p_1 * f1_score_1 + p_2 * f1_score_2 + p_3 * f1_score_3
    
    return accuracy, precision_avg, recall_avg, f1_score_avg

# %% [raw]
# 1 读取训练集，验证集

# %%
# train = pd.read_csv('./data/train_location.csv', usecols=['content', 'label'])
# valid = pd.read_csv('./data/valid_location.csv', usecols=['content', 'label'])

# train = pd.read_csv('./data/train_service.csv', usecols=['content', 'label'])
# valid = pd.read_csv('./data/valid_service.csv', usecols=['content', 'label'])

# train = pd.read_csv('./data/train_price.csv', usecols=['content', 'label'])
# valid = pd.read_csv('./data/valid_price.csv', usecols=['content', 'label'])

# train = pd.read_csv('./data/train_environment.csv', usecols=['content', 'label'])
# valid = pd.read_csv('./data/valid_environment.csv', usecols=['content', 'label'])

train = pd.read_csv('./data/train_dish.csv', usecols=['content', 'label'])
valid = pd.read_csv('./data/valid_dish.csv', usecols=['content', 'label'])

train = shuffle(train, random_state = 2020)
valid = shuffle(valid, random_state = 2020)

train = shuffle(train, random_state = 42)
valid = shuffle(valid, random_state = 42)

print(train.shape)
print(valid.shape)
# Out:
# (105000, 2)
# (15000, 2)

# %%
# 读取 X
# 不同aspect，文本数据一样，不同体现在标签上

train_x = train.content.values.tolist()
valid_x = valid.content.values.tolist()

# print(train_x[0:3])

# %%
# 读取 Y
# 标签
train_y = train.label.values+2
valid_y = valid.label.values+2

# %% [raw]
# tf-idf

# %%
n_features = 1000

tfidf_vectorizer = TfidfVectorizer(
                                        max_df=0.95, 
                                        min_df=2,
                                        max_features=n_features,
                                   )
corpus = train_x + valid_x
print(len(corpus))

t0 = time()
tfidf = tfidf_vectorizer.fit(corpus)
# Out:
# 120000

# %%
print("done in %0.3fs." % (time() - t0))
train_x = tfidf.transform(train_x)
valid_x = tfidf.transform(valid_x)
# Out:
# done in 8.560s.

# %%
print(train_x.shape)
print(valid_x.shape)
# Out:
# (105000, 1000)
# (15000, 1000)

# %% [raw]
# MLP

# %%
# 标准化
scaler = StandardScaler(with_mean=False)
train_x = scaler.fit_transform(train_x)
valid_x = scaler.fit_transform(valid_x)

# %% [raw]
# 调参

# %% [raw]
# 影响模型过拟合，欠拟合的参数：
# hidden_layer_sizes_range = [32, 64, 128, 256] #h越大，拟合能力越强
# alpha_range = [0.1, 0.01, 0.001, 0.0001] #alpha越小，拟合能力越强
# tol_range = [0.01, 0.001, 0.0001] # tol_range 越小，拟合能力越强
#
#
# batch_size = 128 # attention代码里用的128
# learning_rate = 'adaptive'
# learning_rate_init=0.001
# max_iter = 10000

# %%
hidden_layer_sizes_range = [32, 64, 128, 256] # h越大，拟合能力越强
alpha_range = [0.1, 0.01, 0.001, 0.0001] # alpha越小，拟合能力越强
tol_range = [0.01, 0.001, 0.0001] # tol_range 越小，拟合能力越强

# %%
for hidden in hidden_layer_sizes_range:
    for alpha in alpha_range:
        for tol in tol_range:
            print('hidden_layer_sizes: %d' % hidden)
            print('alpha: %f' % alpha)
            print('tol: %f' % tol)
            clf = MLPClassifier(
                                    hidden_layer_sizes = (hidden,),
                                    activation = 'relu',
                                    solver = 'adam',
                                    alpha = alpha,
                                    batch_size = 128,
                                    learning_rate = 'adaptive',
                                    learning_rate_init = 0.001,
                                    max_iter = 10000,
                                    shuffle=True,
                                    random_state = 2020,
                                    tol = tol,
                                    verbose = True,
                                    early_stopping = True,
                                    validation_fraction = 0.1,
                                    n_iter_no_change = 10
                                )
            t0 = time()
            clf.fit(train_x, train_y)
            print("done in %0.3fs." % (time() - t0))
            predict_y = clf.predict(valid_x)
            # predict_prob_y = clf.predict_proba(valid_x)
            # 评价指标值
            accuracy, precision_avg, recall_avg, f1_score_avg = eval_p_r_f1(valid_y, predict_y)
            print('accuracy：%0.5f' % accuracy)
            print('precision_avg: %0.5f' % precision_avg)
            print('recall_avg: %0.5f' % recall_avg)
            print('f1_score_avg: %0.5f' % f1_score_avg)
            print('>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>')
# Validation score did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# done in 62.884s.
# accuracy：0.79460
# precision_avg: 0.76193
# recall_avg: 0.79460
# f1_score_avg: 0.77172
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 64
# alpha: 0.100000
# tol: 0.000100
# Iteration 1, loss = 0.72945211
# Validation score: 0.794381
# Iteration 2, loss = 0.60026919
# Validation score: 0.797048
# Iteration 3, loss = 0.56573819
# Validation score: 0.795333
# Iteration 4, loss = 0.53871437
# Validation score: 0.780190
# Iteration 5, loss = 0.51085867
# Validation score: 0.783810
# Iteration 6, loss = 0.48383136
# Validation score: 0.771524
# Iteration 7, loss = 0.45754402
# Validation score: 0.767810
# Iteration 8, loss = 0.43539905
# Validation score: 0.763524
# Iteration 9, loss = 0.41605673
# Validation score: 0.761619
# Iteration 10, loss = 0.40106066
# Validation score: 0.754571
# Iteration 11, loss = 0.38631747
# Validation score: 0.745143
# Iteration 12, loss = 0.37581528
# Validation score: 0.742381
# Iteration 13, loss = 0.36580456
# Validation score: 0.745238
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# done in 46.139s.
# accuracy：0.79460
# precision_avg: 0.76193
# recall_avg: 0.79460
# f1_score_avg: 0.77172
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 64
# alpha: 0.010000
# tol: 0.010000
# Iteration 1, loss = 0.68859344
# Validation score: 0.796667
# Iteration 2, loss = 0.55424658
# Validation score: 0.795905
# Iteration 3, loss = 0.50654860
# Validation score: 0.791810
# Iteration 4, loss = 0.46284622
# Validation score: 0.776857
# Iteration 5, loss = 0.41790684
# Validation score: 0.776476
# Iteration 6, loss = 0.37545779
# Validation score: 0.762476
# Iteration 7, loss = 0.33707444
# Validation score: 0.758476
# Iteration 8, loss = 0.30266357
# Validation score: 0.750762
# Iteration 9, loss = 0.27328241
# Validation score: 0.751619
# Iteration 10, loss = 0.24850872
# Validation score: 0.739714
# Iteration 11, loss = 0.22514731
# Validation score: 0.735048
# Iteration 12, loss = 0.20526931
# Validation score: 0.731619
# Validation score did not improve more than tol=0.010000 for 10 consecutive epochs. Stopping.
# done in 55.385s.
# accuracy：0.79107
# precision_avg: 0.75583
# recall_avg: 0.79107
# f1_score_avg: 0.76671
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 64
# alpha: 0.010000
# tol: 0.001000
# Iteration 1, loss = 0.68859344
# Validation score: 0.796667
# Iteration 2, loss = 0.55424658
# Validation score: 0.795905
# Iteration 3, loss = 0.50654860
# Validation score: 0.791810
# Iteration 4, loss = 0.46284622
# Validation score: 0.776857
# Iteration 5, loss = 0.41790684
# Validation score: 0.776476
# Iteration 6, loss = 0.37545779
# Validation score: 0.762476
# Iteration 7, loss = 0.33707444
# Validation score: 0.758476
# Iteration 8, loss = 0.30266357
# Validation score: 0.750762
# Iteration 9, loss = 0.27328241
# Validation score: 0.751619
# Iteration 10, loss = 0.24850872
# Validation score: 0.739714
# Iteration 11, loss = 0.22514731
# Validation score: 0.735048
# Iteration 12, loss = 0.20526931
# Validation score: 0.731619
# Validation score did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# done in 49.808s.
# accuracy：0.79107
# precision_avg: 0.75583
# recall_avg: 0.79107
# f1_score_avg: 0.76671
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 64
# alpha: 0
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# done in 60.562s.
# accuracy：0.79307
# precision_avg: 0.76432
# recall_avg: 0.79307
# f1_score_avg: 0.77084
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 64
# alpha: 0.000100
# tol: 0.010000
# Iteration 1, loss = 0.68389277
# Validation score: 0.796095
# Iteration 2, loss = 0.54710413
# Validation score: 0.794857
# Iteration 3, loss = 0.49627364
# Validation score: 0.792381
# Iteration 4, loss = 0.44910077
# Validation score: 0.775714
# Iteration 5, loss = 0.40065840
# Validation score: 0.774286
# Iteration 6, loss = 0.35569642
# Validation score: 0.758571
# Iteration 7, loss = 0.31297902
# Validation score: 0.755714
# Iteration 8, loss = 0.27488386
# Validation score: 0.747714
# Iteration 9, loss = 0.24221574
# Validation score: 0.750381
# Iteration 10, loss = 0.21451724
# Validation score: 0.735810
# Iteration 11, loss = 0.18782062
# Validation score: 0.735524
# Iteration 12, loss = 0.16573977
# Validation score: 0.733143
# Validation score did not improve more than tol=0.010000 for 10 consecutive epochs. Stopping.
# done in 53.001s.
# accuracy：0.78973
# precision_avg: 0.75396
# recall_avg: 0.78973
# f1_score_avg: 0.76530
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 64
# alpha: 0.000100
# tol: 0.001000
# Iteration 1, loss = 0.68389277
# Validation score: 0.796095
# Iteration 2, loss = 0.54710413
# Validation score: 0.794857
# Iteration 3, loss = 0.49627364
# Validation score: 0.792381
# Iteration 4, loss = 0.44910077
# Validation score: 0.775714
# Iteration 5, loss = 0.40065840
# Validation score: 0.774286
# Iteration 6, loss = 0.35569642
# Validation score: 0.758571
# Iteration 7, loss = 0.31297902
# Validation score: 0.755714
# Iteration 8, loss = 0.27488386
# Validation score: 0.747714
# Iteration 9, loss = 0.24221574
# Validation score: 0.750381
# Iteration 10, loss = 0.21451724
# Validation score: 0.735810
# Iteration 11, loss = 0.18782062
# Validation score: 0.735524
# Iteration 12, loss = 0.16573977
# Validation score: 0.733143
# Validation score did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# done in 55.997s.
# accuracy：0.78973
# precision_avg: 0.75396
# recall_avg: 0.78973
# f1_score_avg: 0.76530
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 64
# alpha: 0.000100
# tol: 0.000100
# Iteration 1, loss = 0.68389277
# Validation score: 0.796095
# Iteration 2, loss = 0.54710413
# Validation score: 0.794857
# Iteration 3, loss = 0.49627364
# Validation score: 0.792381
# Iteration 4, loss = 0.44910077
# Validation score: 0.775714
# Iteration 5, loss = 0.40065840
# Validation score: 0.774286
# Iteration 6, loss = 0.35569642
# Validation score: 0.758571
# Iteration 7, loss = 0.31297902
# Validation score: 0.755714
# Iteration 8, loss = 0.27488386
# Validation score: 0.747714
# Iteration 9, loss = 0.24221574
# Validation score: 0.750381
# Iteration 10, loss = 0.21451724
# Validation score: 0.735810
# Iteration 11, loss = 0.18782062
# Validation score: 0.735524
# Iteration 12, loss = 0.16573977
# Validation score: 0.733143
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# done in 55.994s.
# accuracy：0.78973
# precision_avg: 0.75396
# recall_avg: 0.78973
# f1_score_avg: 0.76530
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 128
# alpha: 0
# Validation score did not improve more than tol=0.010000 for 10 consecutive epochs. Stopping.
# done in 78.970s.
# accuracy：0.79133
# precision_avg: 0.75799
# recall_avg: 0.79133
# f1_score_avg: 0.77092
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 128
# alpha: 0.010000
# tol: 0.001000
# Iteration 1, loss = 0.68305046
# Validation score: 0.788381
# Iteration 2, loss = 0.54270291
# Validation score: 0.788667
# Iteration 3, loss = 0.47209562
# Validation score: 0.785905
# Iteration 4, loss = 0.38495482
# Validation score: 0.768000
# Iteration 5, loss = 0.29652840
# Validation score: 0.763905
# Iteration 6, loss = 0.22410561
# Validation score: 0.746000
# Iteration 7, loss = 0.17226496
# Validation score: 0.745714
# Iteration 8, loss = 0.13788881
# Validation score: 0.737810
# Iteration 9, loss = 0.11672774
# Validation score: 0.740095
# Iteration 10, loss = 0.10493866
# Validation score: 0.736000
# Iteration 11, loss = 0.10511165
# Validation score: 0.728286
# Iteration 12, loss = 0.10695851
# Validation score: 0.739238
# Validation score did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# done in 83.071s.
# accuracy：0.79133
# precision_avg: 0.75799
# recall_avg: 0.79133
# f1_score_avg: 0.77092
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 128
# alpha: 0.010000
# tol: 0.000100
# Iteration 1, loss = 0.68305046
# Validation score: 0.788381
# Iteration 2, loss = 0.54270291
# Validation score: 0.788667
# Iteration 3, loss = 0.47209562
# Validation score: 0.785905
# Iteration 4, loss = 0.38495482
# Validation score: 0.768000
# Iteration 5, loss = 0.29652840
# Validation score: 0.763905
# Iteration 6, loss = 0.22410561
# Validation score: 0.746000
# Iteration 7, loss = 0.17226496
# Validation score: 0.745714
# Iteration 8, loss = 0.13788881
# Validation score: 0.737810
# Iteration 9, loss = 0.11672774
# Validation score: 0.740095
# Iteration 10, loss = 0.10493866
# Validation score: 0.736000
# Iteration 11, loss = 0.10511165
# Validation score: 0.728286
# Iteration 12, loss = 0.10695851
# Validation score: 0.739238
# Iteration 13, loss = 0.10187701
# Validation score: 0.731905
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# done in 80.596s.
# accuracy：0.79133
# precision_avg: 0.75799
# recall_avg: 0.79133
# f1_score_avg: 0.77092
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 128
# alpha: 0.001000
# tol: 0.010000
# Iteration 1, loss = 0.67454630
# Validation score: 0.789238
# Iteration 2, loss = 0.53103442
# Validation score: 0.786571
# Iteration 3, loss = 0.45346073
# Validation score: 0.782000
# Iteration 4, loss = 0.35831551
# Validation score: 0.768762
# Iteration 5, loss = 0.26266429
# Validation score: 0.762286
# Iteration 6, loss = 0.18505884
# Validation score: 0.750381
# Iteration 7, loss = 0.12726465
# Validation score: 0.746095
# Iteration 8, loss = 0.08793513
# Validation score: 0.743810
# Iteration 9, loss = 0.06453279
# Validation score: 0.732476
# Iteration 10, loss = 0.05441438
# Validation score: 0.732190
# Iteration 11, loss = 0.05268936
# Validation score: 0.734571
# Iteration 12, loss = 0.04829275
# Validation score: 0.734667
# Validation score did not improve more than tol=0.010000 for 10 consecutive epochs. Stopping.
# done in 73.708s.
# accuracy：0.79553
# precision_avg: 0.76079
# recall_avg: 0.79553
# f1_score_avg: 0.77165
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 128
# alpha: 0.001000
# tol: 0.001000
# Iteration 1, loss = 0.67454630
# Validation score: 0.789238
# Iteration 2, loss = 0.53103442
# Validation score: 0.786571
# Iteration 3, loss = 0.45346073
# Validation score: 0.782000
# Iteration 4, loss = 0.35831551
# Validation score: 0.768762
# Iteration 5, loss = 0.26266429
# Validation score: 0.762286
# Iteration 6, loss = 0.18505884
# Validation score: 0.750381
# Iteration 7, loss = 0.12726465
# Validation score: 0.746095
# Iteration 8, loss = 0.08793513
# Validation score: 0.743810
# Iteration 9, loss = 0.06453279
# Validation score: 0.732476
# Iteration 10, loss = 0.05441438
# Validation score: 0.732190
# Iteration 11, loss = 0.05268936
# Validation score: 0.734571
# Iteration 12, loss = 0.04829275
# Validation score: 0.734667
# Validation score did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# done in 79.815s.
# accuracy：0.79553
# precision_avg: 0.76079
# recall_avg: 0.79553
# f1_score_avg: 0.77165
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 128
# alpha: 0.001000
# tol: 0.000100
# Iteration 1, loss = 0.67454630
# Validation score: 0.789238
# Iteration 2, loss = 0.53103442
# Validation score: 0.786571
# Iteration 3, loss = 0.45346073
# Validation score: 0.782000
# Iteration 4, loss = 0.35831551
# Validation score: 0.768762
# Iteration 5, loss = 0.26266429
# Validation score: 0.762286
# Iteration 6, loss = 0.18505884
# Validation score: 0.750381
# Iteration 7, loss = 0.12726465
# Validation score: 0.746095
# Iteration 8, loss = 0.08793513
# Validation score: 0.743810
# Iteration 9, loss = 0.06453279
# Validation score: 0.732476
# Iteration 10, loss = 0.05441438
# Validation score: 0.732190
# Iteration 11, loss = 0.05268936
# Validation score: 0.734571
# Iteration 12, loss = 0.04829275
# Validation score: 0.734667
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# done in 82.001s.
# accuracy：0.79553
# precision_avg: 0.76079
# recall_avg: 0.79553
# f1_score_avg: 0.77165
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 128
# alpha: 0.000100
# tol: 0.010000
# Iteration 1, loss = 0.67381615
# Validation score: 0.789143
# Iteration 2, loss = 0.52994722
# Validation score: 0.786095
# Iteration 3, loss = 0.45158032
# Validation score: 0.783238
# Iteration 4, loss = 0.35550828
# Validation score: 0.768286
# Iteration 5, loss = 0.25977883
# Validation score: 0.758952
# Iteration 6, loss = 0.18166455
# Validation score: 0.747714
# Iteration 7, loss = 0.12285142
# Validation score: 0.745524
# Iteration 8, loss = 0.08412509
# Validation score: 0.739048
# Iteration 9, loss = 0.06092454
# Validation score: 0.737619
# Iteration 10, loss = 0.04863241
# Validation score: 0.740000
# Iteration 11, loss = 0.04640785
# Validation score: 0.730571
# Iteration 12, loss = 0.04319528
# Validation score: 0.733619
# Validation score did not improve more than tol=0.010000 for 10 consecutive epochs. Stopping.
# done in 73.279s.
# accuracy：0.79520
# precision_avg: 0.76080
# recall_avg: 0.79520
# f1_score_avg: 0.77122
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 128
# alpha: 0.000100
# tol: 0.001000
# Iteration 1, loss = 0.67381615
# Validation score: 0.789143
# Iteration 2, loss = 0.52994722
# Validation score: 0.786095
# Iteration 3, loss = 0.45158032
# Validation score: 0.783238
# Iteration 4, loss = 0.35550828
# Validation score: 0.768286
# Iteration 5, loss = 0.25977883
# Validation score: 0.758952
# Iteration 6, loss = 0.18166455
# Validation score: 0.747714
# Iteration 7, loss = 0.12285142
# Validation score: 0.745524
# Iteration 8, loss = 0.08412509
# Validation score: 0.739048
# Iteration 9, loss = 0.06092454
# Validation score: 0.737619
# Iteration 10, loss = 0.04863241
# Validation score: 0.740000
# Iteration 11, loss = 0.04640785
# Validation score: 0.730571
# Iteration 12, loss = 0.04319528
# Validation score: 0.733619
# Validation score did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# done in 83.079s.
# accuracy：0.79520
# precision_avg: 0.76080
# recall_avg: 0.79520
# f1_score_avg: 0.77122
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 128
# alpha: 0.000100
# tol: 0.000100
# Iteration 1, loss = 0.67381615
# Validation score: 0.789143
# Iteration 2, loss = 0.52994722
# Validation score: 0.786095
# Iteration 3, loss = 0.45158032
# Validation score: 0.783238
# Iteration 4, loss = 0.35550828
# Validation score: 0.768286
# Iteration 5, loss = 0.25977883
# Validation score: 0.758952
# Iteration 6, loss = 0.18166455
# Validation score: 0.747714
# Iteration 7, loss = 0.12285142
# Validation score: 0.745524
# Iteration 8, loss = 0.08412509
# Validation score: 0.739048
# Iteration 9, loss = 0.06092454
# Validation score: 0.737619
# Iteration 10, loss = 0.04863241
# Validation score: 0.740000
# Iteration 11, loss = 0.04640785
# Validation score: 0.730571
# Iteration 12, loss = 0.04319528
# Validation score: 0.733619
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# done in 80.500s.
# accuracy：0.79520
# precision_avg: 0.76080
# recall_avg: 0.79520
# f1_score_avg: 0.77122
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 256
# alpha: 0.100000
# tol: 0.010000
# Iteration 1, loss = 0.80065525
# Validation score: 0.788571
# Iteration 2, loss = 0.64078995
# Validation score: 0.779429
# Iteration 3, loss = 0.58915557
# Validation score: 0.773238
# Iteration 4, loss = 0.53779843
# Validation score: 0.760286
# Iteration 5, loss = 0.47540620
# Validation score: 0.754762
# Iteration 6, loss = 0.42041378
# Validation score: 0.744667
# Iteration 7, loss = 0.38379604
# Validation score: 0.743333
# Iteration 8, loss = 0.36909142
# Validation score: 0.741429
# Iteration 9, loss = 0.35776272
# Validation score: 0.748381
# Iteration 10, loss = 0.35416015
# Validation score: 0.739048
# Iteration 11, loss = 0.34941374
# Validation score: 0.739143
# Iteration 12, loss = 0.34615344
# Validation score: 0.734381
# Validation score did not improve more than tol=0.010000 for 10 consecutive epochs. Stopping.
# done in 132.833s.
# accuracy：0.79487
# precision_avg: 0.76202
# recall_avg: 0.79487
# f1_score_avg: 0.77099
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 256
# alpha: 0.100000
# tol: 0.001000
# Iteration 1, loss = 0.80065525
# Validation score: 0.788571
# Iteration 2, loss = 0.64078995
# Validation score: 0.779429
# Iteration 3, loss = 0.58915557
# Validation score: 0.773238
# Iteration 4, loss = 0.53779843
# Validation score: 0.760286
# Iteration 5, loss = 0.47540620
# Validation score: 0.754762
# Iteration 6, loss = 0.42041378
# Validation score: 0.744667
# Iteration 7, loss = 0.38379604
# Validation score: 0.743333
# Iteration 8, loss = 0.36909142
# Validation score: 0.741429
# Iteration 9, loss = 0.35776272
# Validation score: 0.748381
# Iteration 10, loss = 0.35416015
# Validation score: 0.739048
# Iteration 11, loss = 0.34941374
# Validation score: 0.739143
# Iteration 12, loss = 0.34615344
# Validation score: 0.734381
# Validation score did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# done in 127.981s.
# accuracy：0.79487
# precision_avg: 0.76202
# recall_avg: 0.79487
# f1_score_avg: 0.77099
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 256
# alpha: 0.100000
# tol: 0.000100
# Iteration 1, loss = 0.80065525
# Validation score: 0.788571
# Iteration 2, loss = 0.64078995
# Validation score: 0.779429
# Iteration 3, loss = 0.58915557
# Validation score: 0.773238
# Iteration 4, loss = 0.53779843
# Validation score: 0.760286
# Iteration 5, loss = 0.47540620
# Validation score: 0.754762
# Iteration 6, loss = 0.42041378
# Validation score: 0.744667
# Iteration 7, loss = 0.38379604
# Validation score: 0.743333
# Iteration 8, loss = 0.36909142
# Validation score: 0.741429
# Iteration 9, loss = 0.35776272
# Validation score: 0.748381
# Iteration 10, loss = 0.35416015
# Validation score: 0.739048
# Iteration 11, loss = 0.34941374
# Validation score: 0.739143
# Iteration 12, loss = 0.34615344
# Validation score: 0.734381
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# done in 127.135s.
# accuracy：0.79487
# precision_avg: 0.76202
# recall_avg: 0.79487
# f1_score_avg: 0.77099
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 256
# alpha: 0.010000
# tol: 0.010000
# Iteration 1, loss = 0.68011346
# Validation score: 0.788000
# Iteration 2, loss = 0.52598558
# Validation score: 0.772190
# Iteration 3, loss = 0.41498820
# Validation score: 0.766476
# Iteration 4, loss = 0.27288602
# Validation score: 0.743524
# Iteration 5, loss = 0.16760710
# Validation score: 0.751619
# Iteration 6, loss = 0.12123416
# Validation score: 0.746095
# Iteration 7, loss = 0.10525099
# Validation score: 0.732381
# Iteration 8, loss = 0.11376356
# Validation score: 0.741524
# Iteration 9, loss = 0.12027960
# Validation score: 0.743524
# Iteration 10, loss = 0.11544882
# Validation score: 0.739714
# Iteration 11, loss = 0.11260425
# Validation score: 0.732952
# Iteration 12, loss = 0.10935844
# Validation score: 0.738000
# Validation score did not improve more than tol=0.010000 for 10 consecutive epochs. Stopping.
# done in 130.752s.
# accuracy：0.79473
# precision_avg: 0.76333
# recall_avg: 0.79473
# f1_score_avg: 0.77134
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 256
# alpha: 0.010000
# tol: 0.001000
# Iteration 1, loss = 0.68011346
# Validation score: 0.788000
# Iteration 2, loss = 0.52598558
# Validation score: 0.772190
# Iteration 3, loss = 0.41498820
# Validation score: 0.766476
# Iteration 4, loss = 0.27288602
# Validation score: 0.743524
# Iteration 5, loss = 0.16760710
# Validation score: 0.751619
# Iteration 6, loss = 0.12123416
# Validation score: 0.746095
# Iteration 7, loss = 0.10525099
# Validation score: 0.732381
# Iteration 8, loss = 0.11376356
# Validation score: 0.741524
# Iteration 9, loss = 0.12027960
# Validation score: 0.743524
# Iteration 10, loss = 0.11544882
# Validation score: 0.739714
# Iteration 11, loss = 0.11260425
# Validation score: 0.732952
# Iteration 12, loss = 0.10935844
# Validation score: 0.738000
# Validation score did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# done in 120.829s.
# accuracy：0.79473
# precision_avg: 0.76333
# recall_avg: 0.79473
# f1_score_avg: 0.77134
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 256
# alpha: 0.010000
# tol: 0.000100
# Iteration 1, loss = 0.68011346
# Validation score: 0.788000
# Iteration 2, loss = 0.52598558
# Validation score: 0.772190
# Iteration 3, loss = 0.41498820
# Validation score: 0.766476
# Iteration 4, loss = 0.27288602
# Validation score: 0.743524
# Iteration 5, loss = 0.16760710
# Validation score: 0.751619
# Iteration 6, loss = 0.12123416
# Validation score: 0.746095
# Iteration 7, loss = 0.10525099
# Validation score: 0.732381
# Iteration 8, loss = 0.11376356
# Validation score: 0.741524
# Iteration 9, loss = 0.12027960
# Validation score: 0.743524
# Iteration 10, loss = 0.11544882
# Validation score: 0.739714
# Iteration 11, loss = 0.11260425
# Validation score: 0.732952
# Iteration 12, loss = 0.10935844
# Validation score: 0.738000
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# done in 133.947s.
# accuracy：0.79473
# precision_avg: 0.76333
# recall_avg: 0.79473
# f1_score_avg: 0.77134
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 256
# alpha: 0.001000
# tol: 0.010000
# Iteration 1, loss = 0.66464221
# Validation score: 0.787810
# Iteration 2, loss = 0.50367552
# Validation score: 0.774952
# Iteration 3, loss = 0.37741664
# Validation score: 0.766762
# Iteration 4, loss = 0.22064378
# Validation score: 0.742857
# Iteration 5, loss = 0.11131661
# Validation score: 0.750000
# Iteration 6, loss = 0.05909771
# Validation score: 0.748190
# Iteration 7, loss = 0.03952559
# Validation score: 0.739048
# Iteration 8, loss = 0.03796667
# Validation score: 0.734190
# Iteration 9, loss = 0.06037483
# Validation score: 0.742095
# Iteration 10, loss = 0.05231717
# Validation score: 0.739524
# Iteration 11, loss = 0.03712795
# Validation score: 0.733619
# Iteration 12, loss = 0.02703239
# Validation score: 0.735048
# Validation score did not improve more than tol=0.010000 for 10 consecutive epochs. Stopping.
# done in 125.116s.
# accuracy：0.79500
# precision_avg: 0.76408
# recall_avg: 0.79500
# f1_score_avg: 0.77164
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 256
# alpha: 0.001000
# tol: 0.001000
# Iteration 1, loss = 0.66464221
# Validation score: 0.787810
# Iteration 2, loss = 0.50367552
# Validation score: 0.774952
# Iteration 3, loss = 0.37741664
# Validation score: 0.766762
# Iteration 4, loss = 0.22064378
# Validation score: 0.742857
# Iteration 5, loss = 0.11131661
# Validation score: 0.750000
# Iteration 6, loss = 0.05909771
# Validation score: 0.748190
# Iteration 7, loss = 0.03952559
# Validation score: 0.739048
# Iteration 8, loss = 0.03796667
# Validation score: 0.734190
# Iteration 9, loss = 0.06037483
# Validation score: 0.742095
# Iteration 10, loss = 0.05231717
# Validation score: 0.739524
# Iteration 11, loss = 0.03712795
# Validation score: 0.733619
# Iteration 12, loss = 0.02703239
# Validation score: 0.735048
# Validation score did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# done in 137.343s.
# accuracy：0.79500
# precision_avg: 0.76408
# recall_avg: 0.79500
# f1_score_avg: 0.77164
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 256
# alpha: 0.001000
# tol: 0.000100
# Iteration 1, loss = 0.66464221
# Validation score: 0.787810
# Iteration 2, loss = 0.50367552
# Validation score: 0.774952
# Iteration 3, loss = 0.37741664
# Validation score: 0.766762
# Iteration 4, loss = 0.22064378
# Validation score: 0.742857
# Iteration 5, loss = 0.11131661
# Validation score: 0.750000
# Iteration 6, loss = 0.05909771
# Validation score: 0.748190
# Iteration 7, loss = 0.03952559
# Validation score: 0.739048
# Iteration 8, loss = 0.03796667
# Validation score: 0.734190
# Iteration 9, loss = 0.06037483
# Validation score: 0.742095
# Iteration 10, loss = 0.05231717
# Validation score: 0.739524
# Iteration 11, loss = 0.03712795
# Validation score: 0.733619
# Iteration 12, loss = 0.02703239
# Validation score: 0.735048
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# done in 125.720s.
# accuracy：0.79500
# precision_avg: 0.76408
# recall_avg: 0.79500
# f1_score_avg: 0.77164
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 256
# alpha: 0.000100
# tol: 0.010000
# Iteration 1, loss = 0.66296524
# Validation score: 0.787333
# Iteration 2, loss = 0.50114130
# Validation score: 0.774000
# Iteration 3, loss = 0.37289198
# Validation score: 0.765238
# Iteration 4, loss = 0.21391185
# Validation score: 0.749714
# Iteration 5, loss = 0.10254727
# Validation score: 0.747905
# Iteration 6, loss = 0.04992634
# Validation score: 0.752381
# Iteration 7, loss = 0.03131121
# Validation score: 0.744476
# Iteration 8, loss = 0.03028018
# Validation score: 0.746857
# Iteration 9, loss = 0.04683433
# Validation score: 0.736381
# Iteration 10, loss = 0.04634545
# Validation score: 0.736762
# Iteration 11, loss = 0.02941922
# Validation score: 0.738952
# Iteration 12, loss = 0.01617679
# Validation score: 0.742762
# Validation score did not improve more than tol=0.010000 for 10 consecutive epochs. Stopping.
# done in 130.457s.
# accuracy：0.79440
# precision_avg: 0.76209
# recall_avg: 0.79440
# f1_score_avg: 0.77093
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 256
# alpha: 0.000100
# tol: 0.001000
# Iteration 1, loss = 0.66296524
# Validation score: 0.787333
# Iteration 2, loss = 0.50114130
# Validation score: 0.774000
# Iteration 3, loss = 0.37289198
# Validation score: 0.765238
# Iteration 4, loss = 0.21391185
# Validation score: 0.749714
# Iteration 5, loss = 0.10254727
# Validation score: 0.747905
# Iteration 6, loss = 0.04992634
# Validation score: 0.752381
# Iteration 7, loss = 0.03131121
# Validation score: 0.744476
# Iteration 8, loss = 0.03028018
# Validation score: 0.746857
# Iteration 9, loss = 0.04683433
# Validation score: 0.736381
# Iteration 10, loss = 0.04634545
# Validation score: 0.736762
# Iteration 11, loss = 0.02941922
# Validation score: 0.738952
# Iteration 12, loss = 0.01617679
# Validation score: 0.742762
# Validation score did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.
# done in 124.557s.
# accuracy：0.79440
# precision_avg: 0.76209
# recall_avg: 0.79440
# f1_score_avg: 0.77093
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# hidden_layer_sizes: 256
# alpha: 0.000100
# tol: 0.000100
# Iteration 1, loss = 0.66296524
# Validation score: 0.787333
# Iteration 2, loss = 0.50114130
# Validation score: 0.774000
# Iteration 3, loss = 0.37289198
# Validation score: 0.765238
# Iteration 4, loss = 0.21391185
# Validation score: 0.749714
# Iteration 5, loss = 0.10254727
# Validation score: 0.747905
# Iteration 6, loss = 0.04992634
# Validation score: 0.752381
# Iteration 7, loss = 0.03131121
# Validation score: 0.744476
# Iteration 8, loss = 0.03028018
# Validation score: 0.746857
# Iteration 9, loss = 0.04683433
# Validation score: 0.736381
# Iteration 10, loss = 0.04634545
# Validation score: 0.736762
# Iteration 11, loss = 0.02941922
# Validation score: 0.738952
# Iteration 12, loss = 0.01617679
# Validation score: 0.742762
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# done in 128.956s.
# accuracy：0.79440
# precision_avg: 0.76209
# recall_avg: 0.79440
# f1_score_avg: 0.77093
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

# %% [raw]
# 2 service

# %%
clf = MLPClassifier(
                        hidden_layer_sizes = (32,),
                        activation = 'relu',
                        solver = 'adam',
                        alpha = 0.001,
                        batch_size = 128,
                        learning_rate = 'adaptive',
                        learning_rate_init = 0.001,
                        max_iter = 10000,
                        shuffle=True,
                        random_state = 2020,
                        tol = 0.01,
                        verbose = True,
                        early_stopping = True,
                        validation_fraction = 0.1,
                        n_iter_no_change = 10
                    )

t0 = time()
clf.fit(train_x, train_y)
print("done in %0.3fs." % (time() - t0))
predict_y = clf.predict(valid_x)
# predict_prob_y = clf.predict_proba(valid_x)
# 评价指标值
accuracy, precision_avg, recall_avg, f1_score_avg = eval_p_r_f1(valid_y, predict_y)

print('accuracy：%0.5f' % accuracy)
print('precision_avg: %0.5f' % precision_avg)
print('recall_avg: %0.5f' % recall_avg)
print('f1_score_avg: %0.5f' % f1_score_avg)
print('>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>')
# Out:
# Iteration 1, loss = 1.00129246
# Validation score: 0.647048
# Iteration 2, loss = 0.85572982
# Validation score: 0.654000
# Iteration 3, loss = 0.82261760
# Validation score: 0.646762
# Iteration 4, loss = 0.79443682
# Validation score: 0.643714
# Iteration 5, loss = 0.76908106
# Validation score: 0.639048
# Iteration 6, loss = 0.74541722
# Validation score: 0.634000
# Iteration 7, loss = 0.72562899
# Validation score: 0.627810
# Iteration 8, loss = 0.70916985
# Validation score: 0.629143
# Iteration 9, loss = 0.69299927
# Validation score: 0.623905
# Iteration 10, loss = 0.68046127
# Validation score: 0.618000
# Iteration 11, loss = 0.66826883
# Validation score: 0.619048
# Iteration 12, loss = 0.65881605
# Validation score: 0.610667
# Validation score did not improve more than tol=0.010000 for 10 consecutive epochs. Stopping.
# done in 66.232s.
# accuracy：0.64673
# precision_avg: 0.60509
# recall_avg: 0.64673
# f1_score_avg: 0.60932
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

# %% [raw]
# 3 price

# %%
clf = MLPClassifier(
                        hidden_layer_sizes = (32,),
                        activation = 'relu',
                        solver = 'adam',
                        alpha = 0.001,
                        batch_size = 128,
                        learning_rate = 'adaptive',
                        learning_rate_init = 0.001,
                        max_iter = 10000,
                        shuffle=True,
                        random_state = 2020,
                        tol = 0.01,
                        verbose = True,
                        early_stopping = True,
                        validation_fraction = 0.1,
                        n_iter_no_change = 10
                    )

t0 = time()
clf.fit(train_x, train_y)
print("done in %0.3fs." % (time() - t0))
predict_y = clf.predict(valid_x)
# predict_prob_y = clf.predict_proba(valid_x)
# 评价指标值
accuracy, precision_avg, recall_avg, f1_score_avg = eval_p_r_f1(valid_y, predict_y)

print('accuracy：%0.5f' % accuracy)
print('precision_avg: %0.5f' % precision_avg)
print('recall_avg: %0.5f' % recall_avg)
print('f1_score_avg: %0.5f' % f1_score_avg)
print('>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>')
# Out:
# Iteration 1, loss = 1.10354964
# Validation score: 0.587524
# Iteration 2, loss = 0.96335374
# Validation score: 0.593905
# Iteration 3, loss = 0.93080368
# Validation score: 0.595524
# Iteration 4, loss = 0.90278592
# Validation score: 0.592190
# Iteration 5, loss = 0.87696316
# Validation score: 0.587333
# Iteration 6, loss = 0.85306272
# Validation score: 0.580190
# Iteration 7, loss = 0.83347039
# Validation score: 0.575238
# Iteration 8, loss = 0.81649123
# Validation score: 0.569429
# Iteration 9, loss = 0.80104054
# Validation score: 0.564381
# Iteration 10, loss = 0.78759077
# Validation score: 0.559524
# Iteration 11, loss = 0.77646669
# Validation score: 0.564476
# Iteration 12, loss = 0.76587291
# Validation score: 0.559143
# Validation score did not improve more than tol=0.010000 for 10 consecutive epochs. Stopping.
# done in 64.282s.
# accuracy：0.59400
# precision_avg: 0.56406
# recall_avg: 0.59400
# f1_score_avg: 0.56653
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

# %% [raw]
# 4 environment

# %%
clf = MLPClassifier(
                        hidden_layer_sizes = (32,),
                        activation = 'relu',
                        solver = 'adam',
                        alpha = 0.001,
                        batch_size = 128,
                        learning_rate = 'adaptive',
                        learning_rate_init = 0.001,
                        max_iter = 10000,
                        shuffle=True,
                        random_state = 2020,
                        tol = 0.01,
                        verbose = True,
                        early_stopping = True,
                        validation_fraction = 0.1,
                        n_iter_no_change = 10
                    )

t0 = time()
clf.fit(train_x, train_y)
print("done in %0.3fs." % (time() - t0))
predict_y = clf.predict(valid_x)
# predict_prob_y = clf.predict_proba(valid_x)
# 评价指标值
accuracy, precision_avg, recall_avg, f1_score_avg = eval_p_r_f1(valid_y, predict_y)

print('accuracy：%0.5f' % accuracy)
print('precision_avg: %0.5f' % precision_avg)
print('recall_avg: %0.5f' % recall_avg)
print('f1_score_avg: %0.5f' % f1_score_avg)
print('>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>')
# Out:
# Iteration 1, loss = 0.95341149
# Validation score: 0.675238
# Iteration 2, loss = 0.81123457
# Validation score: 0.684095
# Iteration 3, loss = 0.77914034
# Validation score: 0.679238
# Iteration 4, loss = 0.75176375
# Validation score: 0.680190
# Iteration 5, loss = 0.72618962
# Validation score: 0.673238
# Iteration 6, loss = 0.70425256
# Validation score: 0.667429
# Iteration 7, loss = 0.68460786
# Validation score: 0.661143
# Iteration 8, loss = 0.66749715
# Validation score: 0.652762
# Iteration 9, loss = 0.65330401
# Validation score: 0.658667
# Iteration 10, loss = 0.63999857
# Validation score: 0.653429
# Iteration 11, loss = 0.62779777
# Validation score: 0.650000
# Iteration 12, loss = 0.61790047
# Validation score: 0.649905
# Validation score did not improve more than tol=0.010000 for 10 consecutive epochs. Stopping.
# done in 70.249s.
# accuracy：0.68907
# precision_avg: 0.64075
# recall_avg: 0.68907
# f1_score_avg: 0.64657
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

# %% [raw]
# 5 dish

# %%
clf = MLPClassifier(
                        hidden_layer_sizes = (32,),
                        activation = 'relu',
                        solver = 'adam',
                        alpha = 0.001,
                        batch_size = 128,
                        learning_rate = 'adaptive',
                        learning_rate_init = 0.001,
                        max_iter = 10000,
                        shuffle=True,
                        random_state = 2020,
                        tol = 0.01,
                        verbose = True,
                        early_stopping = True,
                        validation_fraction = 0.1,
                        n_iter_no_change = 10
                    )

t0 = time()
clf.fit(train_x, train_y)
print("done in %0.3fs." % (time() - t0))
predict_y = clf.predict(valid_x)
# predict_prob_y = clf.predict_proba(valid_x)
# 评价指标值
accuracy, precision_avg, recall_avg, f1_score_avg = eval_p_r_f1(valid_y, predict_y)

print('accuracy：%0.5f' % accuracy)
print('precision_avg: %0.5f' % precision_avg)
print('recall_avg: %0.5f' % recall_avg)
print('f1_score_avg: %0.5f' % f1_score_avg)
print('>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>')
# Out:
# Iteration 1, loss = 0.79921953
# Validation score: 0.695333
# Iteration 2, loss = 0.69819248
# Validation score: 0.700571
# Iteration 3, loss = 0.66713951
# Validation score: 0.699714
# Iteration 4, loss = 0.64094907
# Validation score: 0.693429
# Iteration 5, loss = 0.61645216
# Validation score: 0.686762
# Iteration 6, loss = 0.59464975
# Validation score: 0.680667
# Iteration 7, loss = 0.57491549
# Validation score: 0.676476
# Iteration 8, loss = 0.55722720
# Validation score: 0.669238
# Iteration 9, loss = 0.54261450
# Validation score: 0.666952
# Iteration 10, loss = 0.52977499
# Validation score: 0.670857
# Iteration 11, loss = 0.51733043
# Validation score: 0.672286
# Iteration 12, loss = 0.50622859
# Validation score: 0.666762
# Validation score did not improve more than tol=0.010000 for 10 consecutive epochs. Stopping.
# done in 66.807s.
# accuracy：0.69313
# precision_avg: 0.64821
# recall_avg: 0.69313
# f1_score_avg: 0.65135
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
